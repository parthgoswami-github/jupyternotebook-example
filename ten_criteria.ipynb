# %% [markdown]
# To be classified as open source, software distribution terms must adhere to these ten criteria. View the full
# Open Source Definition from the Open Source Initiative here.
#
# <font color="red">To be classified as open source, software distribution terms must adhere to these ten criteria. View the full Open Source Definition from the Open Source Initiative here.</font>
#
#
#
#
#
# ![ten_criteria.png](attachment:ten_criteria.png)
